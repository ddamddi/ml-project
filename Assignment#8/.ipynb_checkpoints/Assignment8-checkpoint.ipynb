# %% [markdown]
# # Assignment 8

# %%
from __future__ import print_function

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
import numpy as np
from tqdm.notebook import trange, tqdm
import matplotlib.pyplot as plt

torch.__version__
# Out:
# '1.2.0'

# %% [markdown]
# ## Load test data and add noises

# %%
class numpyDataset(Dataset):
    def __init__(self, data, transform=None):
        self.data = torch.from_numpy(data).float()
        self.transform = transform
        
    def __getitem__(self, index):
        x = self.data[index]
        
        if self.transform:
            x = self.transform(x)
        
        return x
    
    def __len__(self):
        return len(self.data)

# %%
def activateNoises(imagedata, std_dev):
    noisedata = imagedata + np.random.normal(0, std_dev, imagedata.shape)
    
    noisedata = np.minimum(noisedata, 1)
    noisedata = np.maximum(noisedata, 0)
    
    return noisedata

# %%
noises = [0.1, 0.2, 0.3, 0.4]

transform       = transforms.Compose([
                                transforms.ToPILImage(),
                                transforms.Grayscale(num_output_channels=1),
                                transforms.ToTensor(),
                            ])

# for training
traindata       = np.load('data/train.npy')
traindataset    = numpyDataset(traindata, transform)

noisedata       = activateNoises(traindata, 0.25)
noisedataset    = numpyDataset(noisedata, transform)

trainloader     = DataLoader(traindataset, batch_size=64, shuffle=False, num_workers=0)
noiseloader     = DataLoader(noisedataset, batch_size=64, shuffle=False, num_workers=0)

# %% [markdown]
# ## Define AutoEncoder

# %%
class AutoEncoder(nn.Module):
    
    def __init__(self):
        super(AutoEncoder, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1, 128, 3, stride=1, padding=1),  # b, 16, 10, 10
            nn.ReLU(True),
            nn.MaxPool2d(2, stride=2),  # b, 16, 5, 5
            
            nn.Conv2d(128, 32, 3, stride=1, padding=1),  # b, 16, 10, 10
            nn.ReLU(True),
            nn.MaxPool2d(2, stride=2),
            
            nn.Conv2d(32, 8, 3, stride=1, padding=1),  # b, 8, 3, 3
            nn.ReLU(True),
#             nn.MaxPool2d(2, stride=2),  # b, 8, 2, 2
            
#             nn.Conv2d(8, 1, 3, stride=1, padding=1),  # b, 8, 3, 3
#             nn.ReLU(True), 
        )
        self.decoder = nn.Sequential(
#             nn.ConvTranspose2d(1, 8, 3, stride=1, padding=1),  # b, 16, 5, 5
#             nn.ReLU(True),
            
            nn.ConvTranspose2d(8, 32, 3, stride=1, padding=1),  # b, 16, 5, 5
            nn.ReLU(True),
            
            nn.ConvTranspose2d(32, 128, 2, stride=2),  # b, 8, 15, 15
            nn.ReLU(True),
            
            nn.ConvTranspose2d(128, 1, 2, stride=2),  # b, 8, 15, 15
            nn.Tanh()
            
#             nn.ConvTranspose2d(8, 4, 2, stride=2, padding=0),  # b, 1, 28, 28
#             nn.ReLU(True),
#             nn.ConvTranspose2d(4, 1, 2, stride=2, padding=0),  # b, 1, 28, 28

        )

    def forward(self, x):
        x = self.encoder(x)
#         print(x.shape)
        x = self.decoder(x)
#         print(x.shape)
        return x

# %%
model = AutoEncoder()

bCuda = 1

if bCuda:
    model.cuda()

optimizer   = optim.SGD(model.parameters(), lr=1e-1, weight_decay=1e-5)
objective   = nn.MSELoss()

def train():
    
    loss_train = []
    
    model.train()
    
    trainiter = iter(trainloader)
    
    for idx_batch, data in enumerate(noiseloader):
        
        original = trainiter.next()
        
        if bCuda:
            data = data.cuda()
            original = original.cuda()
        
        data = Variable(data)
        original = Variable(original)

        optimizer.zero_grad()
        output = model(data)
        
        loss = objective(output, original)
        loss.backward()
        optimizer.step()

        loss_train_batch = loss.item()
        loss_train.append(loss_train_batch)
    
    
    loss_train_mean = np.mean(loss_train)
    loss_train_std  = np.std(loss_train)
    
    return {'loss_train_mean': loss_train_mean, 'loss_train_std': loss_train_std }


def test():

    model.eval()
    output  = model(data)

    for idx_batch, (data, target) in enumerate(valloader):

        if bCuda:       
            data, target    = data.cuda(), target.cuda()
        data, target    = Variable(data), Variable(target)

        output  = model(data)
        loss    = objective(output, target)

        loss_test   += loss.item()
        pred        = output.data.max(1)[1]
        correct     += pred.eq(target.data.view_as(pred)).cpu().sum()

    loss_test       = loss_test
    accuracy_test   = 100. * float(correct) / len(valloader.dataset)

    return {'loss_test': loss_test, 'accuracy_test': accuracy_test}

# %%
NUM_EPOCH = 200

for epoch in trange(NUM_EPOCH):
        
    result_train = train()
    
    print("[epoch %5d] loss: (training) %0.5f " % (epoch+1, result_train['loss_train_mean']))
# Out:
# HBox(children=(IntProgress(value=0, max=200), HTML(value='')))
# [epoch     1] loss: (training) 0.02284
# [epoch     2] loss: (training) 0.01931
# [epoch     3] loss: (training) 0.01907
# [epoch     4] loss: (training) 0.01846
# [epoch     5] loss: (training) 0.01644
# [epoch     6] loss: (training) 0.01098
# [epoch     7] loss: (training) 0.00597
# [epoch     8] loss: (training) 0.00525
# [epoch     9] loss: (training) 0.00484
# [epoch    10] loss: (training) 0.00475
# [epoch    11] loss: (training) 0.00472
# [epoch    12] loss: (training) 0.00439
# [epoch    13] loss: (training) 0.00458
# [epoch    14] loss: (training) 0.00449
# [epoch    15] loss: (training) 0.00428
# [epoch    16] loss: (training) 0.00413
# [epoch    17] loss: (training) 0.00396
# [epoch    18] loss: (training) 0.00396
# [epoch    19] loss: (training) 0.00384
# [epoch    20] loss: (training) 0.00396
# [epoch    21] loss: (training) 0.00376
# [epoch    22] loss: (training) 0.00378
# [epoch    23] loss: (training) 0.00365
# [epoch    24] loss: (training) 0.00362
# [epoch    25] loss: (training) 0.00355
# [epoch    26] loss: (training) 0.00350
# [epoch    27] loss: (training) 0.00344
# [epoch    28] loss: (training) 0.00340
# [epoch    29] loss: (training) 0.00336
# [epoch    30] loss: (training) 0.00332
# [epoch    31] loss: (training) 0.00328
# [epoch    32] loss: (training) 0.00325
# [epoch    33] loss: (training) 0.00323
# [epoch    34] loss: (training) 0.00321
# [epoch    35] loss: (training) 0.00319
# [epoch    36] loss: (training) 0.00317
# [epoch    37] loss: (training) 0.00315
# [epoch    38] loss: (training) 0.00314
# [epoch    39] loss: (training) 0.00313
# [epoch    40] loss: (training) 0.00312
# [epoch    41] loss: (training) 0.00311
# [epoch    42] loss: (training) 0.00310
# [epoch    43] loss: (training) 0.00309
# [epoch    44] loss: (training) 0.00308
# [epoch    45] loss: (training) 0.00307
# [epoch    46] loss: (training) 0.00307
# [epoch    47] loss: (training) 0.00306
# [epoch    48] loss: (training) 0.00306
# [epoch    49] loss: (training) 0.00305
# [epoch    50] loss: (training) 0.00304
# [epoch    51] loss: (training) 0.00304
# [epoch    52] loss: (training) 0.00303
# [epoch    53] loss: (training) 0.00303
# [epoch    54] loss: (training) 0.00303
# [epoch    55] loss: (training) 0.00302
# [epoch    56] loss: (training) 0.00302
# [epoch    57] loss: (training) 0.00301
# [epoch    58] loss: (training) 0.00301
# [epoch    59] loss: (training) 0.00301
# [epoch    60] loss: (training) 0.00300
# [epoch    61] loss: (training) 0.00300
# [epoch    62] loss: (training) 0.00300
# [epoch    63] loss: (training) 0.00299
# [epoch    64] loss: (training) 0.00299
# [epoch    65] loss: (training) 0.00299
# [epoch    66] loss: (training) 0.00298
# [epoch    67] loss: (training) 0.00298
# [epoch    68] loss: (training) 0.00298
# [epoch    69] loss: (training) 0.00297
# [epoch    70] loss: (training) 0.00297
# [epoch    71] loss: (training) 0.00297
# [epoch    72] loss: (training) 0.00297
# [epoch    73] loss: (training) 0.00297
# [epoch    74] loss: (training) 0.00296
# [epoch    75] loss: (training) 0.00296
# [epoch    76] loss: (training) 0.00296
# [epoch    77] loss: (training) 0.00296
# [epoch    78] loss: (training) 0.00296
# [epoch    79] loss: (training) 0.00295
# [epoch    80] loss: (training) 0.00295
# [epoch    81] loss: (training) 0.00295
# [epoch    82] loss: (training) 0.00295
# [epoch    83] loss: (training) 0.00295
# [epoch    84] loss: (training) 0.00295
# [epoch    85] loss: (training) 0.00294
# [epoch    86] loss: (training) 0.00294
# [epoch    87] loss: (training) 0.00294
# [epoch    88] loss: (training) 0.00294
# [epoch    89] loss: (training) 0.00294
# [epoch    90] loss: (training) 0.00294
# [epoch    91] loss: (training) 0.00294
# [epoch    92] loss: (training) 0.00293
# [epoch    93] loss: (training) 0.00293
# [epoch    94] loss: (training) 0.00293
# [epoch    95] loss: (training) 0.00293
# [epoch    96] loss: (training) 0.00293
# [epoch    97] loss: (training) 0.00293
# [epoch    98] loss: (training) 0.00293
# [epoch    99] loss: (training) 0.00293
# [epoch   100] loss: (training) 0.00292
# [epoch   101] loss: (training) 0.00292
# [epoch   102] loss: (training) 0.00292
# [epoch   103] loss: (training) 0.00292
# [epoch   104] loss: (training) 0.00292
# [epoch   105] loss: (training) 0.00292
# [epoch   106] loss: (training) 0.00292
# [epoch   107] loss: (training) 0.00292
# [epoch   108] loss: (training) 0.00292
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-e6290f838349> in <module>
#       3 for epoch in trange(NUM_EPOCH):
#       4
# ----> 5     result_train = train()
#       6
#       7     print("[epoch %5d] loss: (training) %0.5f " % (epoch+1, result_train['loss_train_mean']))
#
# <ipython-input-48-263448371de9> in train()
#      35         optimizer.step()
#      36
# ---> 37         loss_train_batch = loss.item()
#      38         loss_train.append(loss_train_batch)
#      39
#
# KeyboardInterrupt:

# %%
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

# %%
# for training
testdata       = np.load('data/test.npy')
testdataset    = numpyDataset(testdata, transform)

noisetestdata       = activateNoises(testdata, 0.25)
noisetestdataset    = numpyDataset(noisetestdata, transform)

testloader     = DataLoader(testdataset, batch_size=64, shuffle=False, num_workers=0)
noisetestloader     = DataLoader(noisetestdataset, batch_size=64, shuffle=False, num_workers=0)

# %%
testiter = iter(testloader)
noiseiter = iter(noisetestloader)

# %%
original = testiter.next()
noises = noiseiter.next()

# %%
imshow(torchvision.utils.make_grid(original))
print(original.shape)

imshow(torchvision.utils.make_grid(noises))
print(noises.shape)

noises = noises.cuda()

output = model(Variable(noises))
print(output.shape)
output = output.cpu().detach()
imshow(torchvision.utils.make_grid(output))

loss = objective(output, original)
print(loss)
# Out:
# torch.Size([64, 1, 120, 80])
# torch.Size([64, 1, 120, 80])
# torch.Size([64, 1, 120, 80])
# tensor(0.0025)
